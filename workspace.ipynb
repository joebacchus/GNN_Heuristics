# %%
# %load_ext autoreload
# %autoreload 2
import torch
from support import load_graph
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
out = load_graph(200, 3, None, "Random regular", 1, 30, "Greedy modularity")

# %%
nx.draw(out)

# %%
benchmarks_reader("Max",5,0.3,"Random regular")
# Out:
# (-1.673, 0.001)

# %%
values = [(benchmarks_reader("Max",k,0.3,"Random regular"),k) for k in range(1,30)]
values = [(y[0][0],y[1]) for y in values if y[0] is not None]

# %%
xs = np.array(values).T[0]
ys = np.array(values).T[1]

# %%
plt.scatter(xs,ys)
slope, intercept = np.polyfit(ys, xs, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.scatter(xs,ys)
# ----> 2 slope, intercept = np.polyfit(ys, xs, 2)
#
# ValueError: too many values to unpack (expected 2)

# %%
def predict_benchmark(k):
    prediction = (k - (-9.675808573724105) ) / (-8.69340193226905)
    return prediction

# %%
predict_benchmark(20)
# Out:
# -3.413601350188404

# %%
energy_stats = np.array([0,0,0])

# %%
energy_stats[0] = 1

# %%
energy_stats
# Out:
# array([1, 0, 0])

# %%
torch.linspace(2,0,200).exp()[0]
# Out:
# tensor(7.3891)
